# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, accuracy_score, roc_auc_score, confusion_matrix, precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing, neighbors

# %% [markdown]
# # EDA

# %% [markdown]
# ### Unbalanced Data

# %%
# Heat Map
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# ### Balanced Data

# %%
# Heat Map
plt.figure(figsize=(10,10))
sns.heatmap(df_new.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_Temp.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# pairplot
sns.pairplot(df_new, hue='label');

# %%
# Distribution

# %%
#Label count

# %%
#Ransomware and white distribution over years 
sns.displot(data=df_new, x="year", col="label", kind="kde");

# %% [markdown]
# ### EDA with transformation

# %%
df_transformed.columns
# Out:
# Index(['address', 'year', 'day', 'length', 'weight', 'count', 'looped',
#        'neighbors', 'income', 'label', 'length_t', 'weight_t', 'count_t',
#        'looped_t', 'neighbors_t', 'income_t'],
#       dtype='object')

# %%
sns.heatmap(df_transformed.drop(columns=['length', 'weight', 'count', 'looped',
       'neighbors', 'income']).corr(), annot=True);

# %%
df_transformed['address']
# Out:
# 0         111K8kZAEnJg245r2cM6y9zgJGHZtJPy6
# 1        1123pJv8jzeFQaCV4w644pzQJzVWay2zcA
# 2        112536im7hy6wtKbpH1qYDWtTyMRAcA2p7
# 3        1126eDRw2wqSkWosjTCre8cjjQW8sSeWH7
# 4        1129TSjKtx65E35GiUo4AYVeyo48twbrGX
#                         ...
# 82821    13z35f5oZ86gGqjrgHem4uCnWvEFDwieeU
# 82822    1AC9Medf4278cJTpiFp71EdSnzmQDsvTpG
# 82823    1Ae8zykwEQvRMbM2ZGiPq2ttz9Vo8NK6kL
# 82824    1Lb4DiT26zcZasGHHKFoD6gWeqZTsfZ9ya
# 82825    1GBLP15QCD6dDoMuVEWXP5Wr28bcKZSTWu
# Name: address, Length: 82826, dtype: object

# %%
df_transformed['address']
# Out:
# 0            0
# 1            5
# 2            6
# 3            8
# 4            9
#          ...
# 82821     5214
# 82822    20804
# 82823    21980
# 82824    46995
# 82825    36051
# Name: address, Length: 82826, dtype: int32

# %%
fig = sns.pairplot(df_transformed.drop(columns=['length', 'weight', 'count', 'looped', 'neighbors', 'income']), hue='label')
